# %%
# Step 1: Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from math import sqrt

# Step 2: Load dataset
df = pd.read_csv('/content/ch3_airline_passengers.csv')
df.columns = ['Month', 'Passengers']
df['Month'] = pd.to_datetime(df['Month'])
df.set_index('Month', inplace=True)

# Step 3: Normalize the data
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df[['Passengers']])

# Step 4: Create sequences
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(seq_length, len(data)):
        X.append(data[i-seq_length:i])
        y.append(data[i])
    return np.array(X), np.array(y)

sequence_length = 12  # previous 12 months to predict next month
X, y = create_sequences(scaled_data, sequence_length)

# Step 5: Train-test split
train_size = int(len(X) * 0.8)
X_train, y_train = X[:train_size], y[:train_size]
X_test, y_test = X[train_size:], y[train_size:]

# Step 6: Reshape for LSTM [samples, timesteps, features]
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# Step 7: Build LSTM model
model = Sequential()
model.add(LSTM(64, activation='relu', return_sequences=False, input_shape=(sequence_length, 1)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# Step 8: Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=16, validation_split=0.1, verbose=1)

# Step 9: Predict and inverse transform
y_pred = model.predict(X_test)
y_pred_inv = scaler.inverse_transform(y_pred)
y_test_inv = scaler.inverse_transform(y_test)

# Step 10: Plot results
plt.figure(figsize=(12,6))
plt.plot(y_test_inv, label='Actual')
plt.plot(y_pred_inv, label='LSTM Forecast', color='red')
plt.title('LSTM Forecast vs Actual – Airline Passengers')
plt.legend()
plt.show()

# Step 11: Evaluate performance
rmse = sqrt(mean_squared_error(y_test_inv, y_pred_inv))
print(f'RMSE: {rmse:.2f}')
# Out:
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - loss: 0.0927 - val_loss: 0.2479
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0696 - val_loss: 0.1739
# Epoch 3/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0420 - val_loss: 0.1016
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0200 - val_loss: 0.0400
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0118 - val_loss: 0.0155
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0130 - val_loss: 0.0168
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0101 - val_loss: 0.0253
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0094 - val_loss: 0.0256
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0063 - val_loss: 0.0208
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0080 - val_loss: 0.0158
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0083 - val_loss: 0.0153
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0052 - val_loss: 0.0162
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0057 - val_loss: 0.0158
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0058 - val_loss: 0.0169
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0051 - val_loss: 0.0170
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0047 - val_loss: 0.0169
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0050 - val_loss: 0.0229
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0048 - val_loss: 0.0210
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0047 - val_loss: 0.0241
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0054 - val_loss: 0.0233
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0049 - val_loss: 0.0209
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0054 - val_loss: 0.0222
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0049 - val_loss: 0.0234
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0046 - val_loss: 0.0200
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0048 - val_loss: 0.0214
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0037 - val_loss: 0.0206
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0043 - val_loss: 0.0217
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0045 - val_loss: 0.0203
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0041 - val_loss: 0.0220
# Epoch 30/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0040 - val_loss: 0.0197
# Epoch 31/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0040 - val_loss: 0.0242
# Epoch 32/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0050 - val_loss: 0.0200
# Epoch 33/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0043 - val_loss: 0.0214
# Epoch 34/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0046 - val_loss: 0.0184
# Epoch 35/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0046 - val_loss: 0.0223
# Epoch 36/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0039 - val_loss: 0.0183
# Epoch 37/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0042 - val_loss: 0.0206
# Epoch 38/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0038 - val_loss: 0.0190
# Epoch 39/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0035 - val_loss: 0.0210
# Epoch 40/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0039 - val_loss: 0.0229
# Epoch 41/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0043 - val_loss: 0.0147
# Epoch 42/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0047 - val_loss: 0.0252
# Epoch 43/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0042 - val_loss: 0.0190
# Epoch 44/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0038 - val_loss: 0.0147
# Epoch 45/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0037 - val_loss: 0.0305
# Epoch 46/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0047 - val_loss: 0.0166
# Epoch 47/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0033 - val_loss: 0.0184
# Epoch 48/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0036 - val_loss: 0.0227
# Epoch 49/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0042 - val_loss: 0.0167
# Epoch 50/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0034 - val_loss: 0.0242
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# RMSE: 110.80
